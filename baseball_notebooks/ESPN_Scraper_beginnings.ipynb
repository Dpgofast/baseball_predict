# %%
import requests 
from bs4 import BeautifulSoup as bs
import urllib

# %%
r = requests.get('https://www.espn.com/mlb/playbyplay?gameId=401169083')

# %%
soup = bs(r.text, 'html')

# %%
soup.text
currents = soup.find_all('tr',('class'== 'pitch-ball'))
pitch = soup.find_all('ul',{'class'=='css-accordian'})

# %%
pitch
# Out:
# [<ul class="dropdown-menu league-nav med"></ul>,
#  <ul class="dropdown-menu conference-nav med"></ul>,
#  <ul class="dropdown-menu date-nav med"></ul>,
#  <ul id="leagues"></ul>,
#  <ul class="tools"><li class="search">
#  <a class="icon-font-after icon-search-solid-after" href="#" id="global-search-trigger"></a>
#  <div class="global-search" id="global-search">
#  <input class="search-box" placeholder="Search Sports, Teams or Players..." type="text"/><input class="btn-search" type="submit"/>
#  </div></li><li class="user" data-behavior="favorites_mgmt"></li><li id="scores-link"><a data-route="false" href="#" id="global-scoreboard-trigger">Scores</a></li></ul>,
#  <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
# ...

# %%
pitch.find('td')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-d31a81e2af39> in <module>
# ----> 1 pitch.find('td')
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?
